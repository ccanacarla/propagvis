# %%
# LOAD LIBRARIES
from lib.propagationsimulator import PropagationSimulator
from IPython.display import HTML
from lib.location import Location
#%matplotlib inline
import numpy as np

# %%
location = Location('zacatecas.geojson', 'area', equal_density=True, density=0.000000010, plot=True)
# Out:
# /home/aninha/Documentos/Doutorado/PropagVIS/venv36/lib/python3.6/site-packages/geopandas/plotting.py:404: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   "'color'.", UserWarning)

# %% [markdown]
# # =================================================
# # DISTANCE

# %% [markdown]
# ### DIST_LARGE

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-3df7')
seeds = [54]
location.create_seeds_config(seeds, 0.2, plot = False)
sim = PropagationSimulator(location)
sim.set_params(0.5, 0.1, 0.2)
sim.run()
sim.animation(1.5)
sim.export_history(1.5)
# Out:
# /home/aninha/Documentos/Doutorado/PropagVIS/venv36/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %% [markdown]
# ### DIST_SHORT

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [34]
location.create_seeds_config(seeds, 0.2, plot = False)
all_sublocs = location.data.index.values
not_vacc = [37, 53, 23, 51, 34, 52, 15, 35, 8, 11,16]
vacc = np.delete(all_sublocs, not_vacc)
location.vaccinate(vacc)
sim = PropagationSimulator(location)
sim.set_params(0.3, 0.1, 0.2)
sim.run()
sim.animation(1.5)
sim.export_history(0.8)

# %% [markdown]
# ### DIST_LARGE

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [39]
location.create_seeds_config(seeds, 0.8, plot = False)
sim = PropagationSimulator(location)
sim.set_params(0.3, 0.3, 0.2)
sim.run()
sim.animation(1.5)
sim.export_history(2)

# %%
sim.export_history(1.5)

# %%
sim.export_history(2)

# %% [markdown]
# # =================================================
# # DIRECTION

# %% [markdown]
# ### DIR_ONE

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [26]
location.create_seeds_config(seeds, 0.2, plot=False)
all_sublocs = location.data.index.values
not_vacc = [25, 13, 21, 28, 40, 6, 20, 48, 50, 38, 4, 39, 10, 12, 36, 31, 49, 31, 55, 19, 41, 44, 30, 16, 30]
vacc = np.delete(all_sublocs, not_vacc)
location.vaccinate(vacc)
sim = PropagationSimulator(location)
sim.set_params(0.5, 0.1, 0.3)
sim.run()
sim.export_history(1)
# Out:
# /home/varaya/Projects/GeoTimePropagation/4_data_exploration/geoPropDataExploration/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %% [markdown]
# ### DIR_ALL

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [10]
location.create_seeds_config(seeds, 0.2, plot=False)
vacc = [26, 7, 9, 14, 42, 29, 46, 17, 8, 24, 23, 34, 52]
location.vaccinate(vacc)
sim = PropagationSimulator(location)
sim.set_params(0.5, 0.1, 0.3)
sim.run()
sim.export_history(0.5)
# Out:
# /home/varaya/Projects/GeoTimePropagation/4_data_exploration/geoPropDataExploration/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
sim.export_history(0.5)

# %% [markdown]
# ### DIR_ONE

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [54]
location.create_seeds_config(seeds, 0.4, plot=False)
all_sublocs = location.data.index.values
not_vacc = [49, 55, 31, 36, 5, 12, 19, 25, 10, 40, 39, 38, 4, 40, 28, 41, 13, 50, 11, 16]
vacc = np.delete(all_sublocs, not_vacc)
location.vaccinate(vacc)
sim = PropagationSimulator(location)
sim.set_params(0.5, 0.1, 0.3)
sim.run()
sim.export_history(1)
# Out:
# /home/varaya/Projects/GeoTimePropagation/4_data_exploration/geoPropDataExploration/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
sim.export_history(0.3)

# %% [markdown]
# # =================================================
# # SPEED

# %% [markdown]
# ### SPEED_1HALF

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [46]
location.create_seeds_config(seeds, 0.2, plot=False)
sim = PropagationSimulator(location)
sim.set_params(0.5, 0.1, 0.3)
sim.run()
sim.export_history(1)

# %%
sim.export_history(2)

# %% [markdown]
# ### SPEED_2HALF

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [6]
location.create_seeds_config(seeds, 0.2, plot=False)
sim = PropagationSimulator(location)
sim.set_params(0.5, 0.1, 0.3)
sim.run()
sim.export_history(1)

# %%
sim.export_history(0.7)

# %% [markdown]
# ### SPEED_1HALF

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [7]
location.create_seeds_config(seeds, 0.2, plot=False)
sim = PropagationSimulator(location)
sim.set_params(0.5, 0.1, 0.3)
sim.run()
sim.export_history(1)

# %% [markdown]
# # =================================================
# # JUMPS

# %% [markdown]
# ### JUMPS_TRUE

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [30]
location.create_seeds_config(seeds, 0.8, plot=False)
links = [(54, 37), (54, 13), (54, 26)]
location.link_sublocs(links)
sim = PropagationSimulator(location)
sim.set_params(0.1, 0.1, 0.3)
sim.run()
sim.export_history(2)

# %% [markdown]
# ### JUMPS_FALSE

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [50]
location.create_seeds_config(seeds, 0.8, plot=False)
sim = PropagationSimulator(location)
sim.set_params(0.1, 0.1, 0.3)
sim.run()
sim.animation(1)
sim.export_history(2)

# %% [markdown]
# ### JUMPS_TRUE

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [9]
location.create_seeds_config(seeds, 1, plot=False)
links = [(7, 40), (7, 35), (7, 33)]
location.link_sublocs(links)
sim = PropagationSimulator(location)
sim.set_params(0.1, 0.1, 0.3)
sim.run()
sim.export_history(2)

# %% [markdown]
# # =================================================
# # HIGH

# %% [markdown]
# ### HIGH_2HALF

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [53]
location.create_seeds_config(seeds, 0.8, plot=False)
sim = PropagationSimulator(location)
sim.set_params(0.5, 0.1, 0.1)
sim.run()
sim.export_history(1.2)

# %%
sim.export_history(0.9)

# %% [markdown]
# ### HIGH_1HALF

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [50]
location.create_seeds_config(seeds, 0.8, plot=False)
sim = PropagationSimulator(location)
sim.set_params(0.5, 0.1, 0.1)
sim.run()
sim.export_history(1)

# %% [markdown]
# ### HIGH_2HALF

# %%
# CREATE COUNTRY
location = Location.from_identifier('zacatecas-f53b')
seeds = [41]
location.create_seeds_config(seeds, 0.8, plot=False)
location.vaccinate([25])
sim = PropagationSimulator(location)
sim.set_params(0.5, 0.1, 0.1)
sim.run()
sim.export_history(1)

# %%
sim.export_history(0.9)
