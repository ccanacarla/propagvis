# %%
# LOAD LIBRARIES
from lib.propagationsimulator import PropagationSimulator
from IPython.display import HTML
from lib.location import Location
from lib.gridlocation import GridLocation
#%matplotlib inline
import numpy as np

# %%
import json

def make_grid_geojson(H=10, W=10, cell_size=3.0, out="grid_64x64.geojson"):
    feats = []
    for i in range(H):
        for j in range(W):
            x0, y0 = j * cell_size, i * cell_size
            x1, y1 = x0 + cell_size, y0 + cell_size
            cx, cy = (x0 + x1) / 2.0, (y0 + y1) / 2.0
            idx = i * W + j

            feats.append({
                "type": "Feature",
                "properties": {
                    "area": cell_size ** 2,       # área
                    "centroid_x": cx,
                    "centroid_y": cy,
                    "id": idx
                },
                "geometry": {
                    "type": "Polygon",
                    "coordinates": [[
                        [x0, y0],
                        [x1, y0],
                        [x1, y1],
                        [x0, y1],
                        [x0, y0]
                    ]]
                }
            })

    geojson = {
        "type": "FeatureCollection",
        "crs": {
            "type": "name",
            "properties": {
                "name": "urn:ogc:def:crs:OGC:1.3:CRS84"
            }
        },
        "features": feats
    }

    with open(out, "w", encoding="utf-8") as f:
        json.dump(geojson, f, ensure_ascii=False, indent=2)

# gerar exemplo
make_grid_geojson(H=20, W=20, cell_size=1.0, out="data/grid_64x64.geojson")

# %%
location = Location('grid_64x64.geojson', 'area', equal_density=True, density=20, plot=True)
# Out:
# /home/aninha/Documentos/Doutorado/Proj1d/venv36/lib/python3.6/site-packages/geopandas/plotting.py:404: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   "'color'.", UserWarning)

# %%
base = 'grid_64x64-5344'

# %% [markdown]
# Dist_large

# %%
# CREATE COUNTRY
location = Location.from_identifier(base)
seeds = [262,373]
location.create_seeds_config(seeds, 0.2, plot = False)
sim = PropagationSimulator(location)
sim.set_params(0.5, 0.1, 0.2)
sim.run()
sim.animation(1.5)
sim.export_history(1.5)
# Out:
# /home/aninha/Documentos/Doutorado/PropagVIS/venv36/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# /home/aninha/Documentos/Doutorado/PropagVIS/venv36/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %% [markdown]
# Dist_short

# %%
# CREATE COUNTRY
location = Location.from_identifier(base)
seeds = [34]
location.create_seeds_config(seeds, 0.2, plot = False)
all_sublocs = location.data.index.values
not_vacc = [35, 55, 54, 75, 56, 76, 77, 96, 97, 98,36]
vacc = np.delete(all_sublocs, not_vacc)
location.vaccinate(vacc)
sim = PropagationSimulator(location)
sim.set_params(0.3, 0.1, 0.2)
sim.run()
sim.animation(1.5)
sim.export_history(0.8)
# Out:
# /home/aninha/Documentos/Doutorado/PropagVIS/venv36/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
# CREATE COUNTRY
location = Location.from_identifier(base)
seeds = [175]
location.create_seeds_config(seeds, 0.8, plot = False)
sim = PropagationSimulator(location)
sim.set_params(0.3, 0.3, 0.2)
sim.run()
sim.animation(1.5)
sim.export_history(2)
# Out:
# /home/aninha/Documentos/Doutorado/PropagVIS/venv36/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
# CREATE COUNTRY
location = Location.from_identifier(base)
seeds = [26]
location.create_seeds_config(seeds, 0.2, plot=False)
all_sublocs = location.data.index.values
not_vacc = [25, 13, 21, 28, 40, 6, 20, 48, 50, 38, 4, 39, 10, 12, 36, 31, 49, 31, 55, 19, 41, 44, 30, 16, 30]
vacc = np.delete(all_sublocs, not_vacc)
location.vaccinate(vacc)
sim = PropagationSimulator(location)
sim.set_params(0.5, 0.1, 0.3)
sim.run()
sim.animation(1.5)
sim.export_history(1)
# Out:
# /home/aninha/Documentos/Doutorado/PropagVIS/venv36/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# /home/aninha/Documentos/Doutorado/PropagVIS/venv36/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
# CREATE COUNTRY
location = Location.from_identifier(base)
seeds = [165]
location.create_seeds_config(seeds, 0.2, plot=False)
vacc = [164,144,145,146,147,148,168,169]
location.vaccinate(vacc)
sim = PropagationSimulator(location)
sim.set_params(0.5, 0.1, 0.3)
sim.run()
sim.animation(1.5)
sim.export_history(0.5)
# Out:
# /home/aninha/Documentos/Doutorado/PropagVIS/venv36/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
